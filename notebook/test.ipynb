# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Récupérer le contenu html de la page:
#
# On prendra le soin de définir quelques variables avant: url et headers

# %%
url = "https://www.expat-dakar.com"
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:64.0) Gecko/20100101 Firefox/64.0'
}

response = requests.get(url, 
                        headers=headers)

# %% [markdown]
# # Confirmer que le html a été téléchargé avec succès

# %%
print(response.status_code)
# Out:
# 200

# %% [markdown]
# # Sauvegarder le contenu html dans une variable

# %%
html_data = response.text

# %% [markdown]
# # Exploration du contenu html avec BeautifulSoup
#
# On prendra la peine de définir quelques variables

# %%
soup = BeautifulSoup(html_data)

# %%
mw_jump_links = soup.find_all('div')
print(mw_jump_links)
# Out:
# [<div class="wrap"><div class="ad ad--970-90 home-ad home-ad--desktop-header"><div class="ad__outer"><div class="ad__inner" data-ad='{"position":"desktop_header","route":"homeClassified","width":970,"height":90,"dfp":{"path":"\/59134517\/ED_HomeClassified_DH_970x90","id":"22395324735"},"bids":[],"url":"#","picture":null}' id="22395324735"></div></div></div><div class="header-bar"><div class="header-bar__inner"><div class="header-auth"><a class="btn btn-default header-auth__item" href="https://www.expat-dakar.com/compte/login">
# Connexion / Inscription
# </a></div></div></div><header class="header" data-sticky='{"type":"header"}'><div class="header__inner"><a class="header-logo" href="https://www.expat-dakar.com"><span class="header-logo__brand">
# Expat-Dakar
# </span><img alt="Expat-Dakar" class="header-logo__img" src="https://www.expat-dakar.com/assets/ed-site/img/logo-colour.074b1f6c.svg"/></a><span class="header-spacer"> </span><div class="header-cta"><a class="btn btn-secondary header-cta__button" href="https://www.expat-dakar.com/compte/listing/create/listing"><span class="header-cta__button-title">
# Vendre
# </span></a></div><span class="header-menu-toggle"><a aria-label="Menu" class="btn header-menu-toggle__button" data-menu-nav-toggle="" href="#"><svg aria-hidden="true" class="i i-menu header-menu-toggle__button-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#menu"></use></svg></a></span><div class="global-search"><div class="global-search__inner"><form accept-charset="UTF-8" action="https://www.expat-dakar.com/annonces" class="global-search__form" method="GET"><div class="global-search__query"><label class="sr-only" for="q">Recherche par texte</label><input class="form-control autocomplete global-search__query-input" data-autocomplete='{"appendTo":".global-search__inner"}' data-url="https://www.expat-dakar.com/ajax/suggestions?is_business=0" id="q" name="q" placeholder="Je recherche..." type="text"/><svg aria-hidden="true" class="i i-magnify global-search__query-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#magnify"></use></svg></div><div class="global-search__button"><button class="btn btn-primary global-search__button-btn" type="submit">
# Rechercher
# </button></div></form></div></div></div></header><nav class="header-nav" data-header-nav=""><div class="header-nav__inner-container"><ul class="header-nav__inner"><li class="header-nav__inner__item header-nav__inner__item--all"><a class="header-nav__inner__item__link" href="https://www.expat-dakar.com/annonces"><svg aria-hidden="true" class="i i-categories header-nav__inner__item__category-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#categories"></use></svg>
# Autres Catégories
# </a></li><li class="header-nav__inner__item"><a class="header-nav__inner__item__link" href="https://www.expat-dakar.com/vehicules">
# Véhicules
# </a></li><li class="header-nav__inner__item"><a class="header-nav__inner__item__link" href="https://www.expat-dakar.com/emploi">
# Offres d'emploi
# </a></li><li class="header-nav__inner__item"><a class="header-nav__inner__item__link" href="https://www.expat-dakar.com/immobilier">
# Immobilier
# </a></li><li class="header-nav__inner__item"><a class="header-nav__inner__item__link" href="https://www.expat-dakar.com/multimedia">
# Multimédia
# </a></li><li class="header-nav__inner__item"><a class="header-nav__inner__item__link" href="https://www.expat-dakar.com/maison">
# Maison
# </a></li><li class="header-nav__inner__item header-nav__inner__item--businesses"><a class="header-nav__inner__item__link header-nav__inner__item__link--businesses" href="https://www.expat-dakar.com/showroom"><svg aria-hidden="true" class="i i-briefcase header-nav__inner__item__category-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#briefcase"></use></svg>
# Showrooms
# </a></li></ul></div></nav><div class="home-items"><div class="home-header"><div class="home-header__container"><h1 class="home-header__title">
# Tout acheter, tout vendre, tout simplement
# </h1></div></div><div class="home-categories"><div class="home-categories__container"><div class="home-categories__header"><h3 class="home-categories__header__title">
# Catégories
# </h3><a class="home-categories__header__btn" href="https://www.expat-dakar.com/annonces">
# Tout voir
# </a></div><div class="home-categories__content"><div class="home-categories__item"><div class="home-category" data-home-category=""><a class="home-category__header" data-home-category-trigger="" href="https://www.expat-dakar.com/vehicules"><span class="home-category__header__icon"><svg aria-hidden="true" class="i i-vehicles home-category__header__icon-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#vehicles"></use></svg></span><span class="home-category__header__title">
# Véhicules
# </span><span class="home-category__header__toggle"><svg aria-hidden="true" class="i i-chevron-down home-category__header__toggle-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-down"></use></svg></span></a><div class="home-category__content"><ul class="home-category__list"><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/voitures">
# Voitures
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/motos-scooters">
# Motos &amp; scooters
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/equipements-pieces">
# Équipements &amp; pièces
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/location-de-voiture">
# Location de voiture
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/utilitaires-vans-minibus">
# Utilitaires, vans &amp; minibus
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/camions-semi-remorques">
# Camions &amp; semi-remorques
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/engins-agricoles-chantier">
# Engins agricoles et de chantier
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/bateaux">
# Bateaux
# </a></li></ul><a class="home-category__cta" href="https://www.expat-dakar.com/vehicules"><span class="home-category__cta__title">
# Tout parcourir
# </span><span class="home-category__cta__count badge">
# 3855
# </span></a></div></div></div><div class="home-categories__item"><div class="home-category" data-home-category=""><a class="home-category__header" data-home-category-trigger="" href="https://www.expat-dakar.com/emploi"><span class="home-category__header__icon"><svg aria-hidden="true" class="i i-jobs home-category__header__icon-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#jobs"></use></svg></span><span class="home-category__header__title">
# Offres d'emploi
# </span><span class="home-category__header__toggle"><svg aria-hidden="true" class="i i-chevron-down home-category__header__toggle-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-down"></use></svg></span></a><div class="home-category__content"><ul class="home-category__list"><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-vente-commercial">
# Emploi vente et commercial
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-services-a-la-personne">
# Emploi services à la personne
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-enseignement-formation">
# Emploi enseignement et formation
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-marketing-communication">
# Emploi marketing et communication
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-comptabilite-finance-audit">
# Emploi comptabilité, finance et audit
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-service-client-support-technique">
# Emploi service client et support technique
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-administratif">
# Emploi administratif
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-hotellerie-tourisme-loisirs">
# Emploi hôtellerie, tourisme et loisirs
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-hygiene-securite">
# Emploi hygiène et sécurité
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-restauration">
# Emploi restauration
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-transport-logistique">
# Emploi transport et logistique
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-btp-construction-architecture">
# Emploi BTP, construction et architecture
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-informatique">
# Emploi informatique
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-management-business-development">
# Emploi management et business development
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-medical-sante">
# Emploi médical et santé
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-achat">
# Emploi achat
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-graphisme-design">
# Emploi graphisme et design
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-agricole">
# Emploi agricole
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-immobilier">
# Emploi immobilier
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-qualite">
# Emploi qualité
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-r-et-d-science">
# Emploi R&amp;D et science
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-ressources-humaines">
# Emploi ressources humaines
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/emploi-securite">
# Emploi sécurité
# </a></li></ul><a class="home-category__cta" href="https://www.expat-dakar.com/emploi"><span class="home-category__cta__title">
# Tout parcourir
# </span><span class="home-category__cta__count badge">
# 149
# </span></a></div></div></div><div class="home-categories__item"><div class="home-category" data-home-category=""><a class="home-category__header" data-home-category-trigger="" href="https://www.expat-dakar.com/immobilier"><span class="home-category__header__icon"><svg aria-hidden="true" class="i i-home home-category__header__icon-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#home"></use></svg></span><span class="home-category__header__title">
# Immobilier
# </span><span class="home-category__header__toggle"><svg aria-hidden="true" class="i i-chevron-down home-category__header__toggle-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-down"></use></svg></span></a><div class="home-category__content"><ul class="home-category__list"><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/appartements-a-louer">
# Appartements à louer
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/appartements-meubles">
# Appartements meublés
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/terrains-a-vendre">
# Terrains à vendre
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/maisons-a-vendre">
# Maisons à vendre
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/maisons-a-louer">
# Maisons à louer
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/appartements-a-vendre">
# Appartements à vendre
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/chambres-a-louer">
# Chambres à louer
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/proprietes-commerciales-a-louer">
# Propriétés commerciales à louer
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/proprietes-commerciales-a-vendre">
# Propriétés commerciales à vendre
# </a></li></ul><a class="home-category__cta" href="https://www.expat-dakar.com/immobilier"><span class="home-category__cta__title">
# Tout parcourir
# </span><span class="home-category__cta__count badge">
# 1783
# </span></a></div></div></div><div class="home-categories__item"><div class="home-category" data-home-category=""><a class="home-category__header" data-home-category-trigger="" href="https://www.expat-dakar.com/multimedia"><span class="home-category__header__icon"><svg aria-hidden="true" class="i i-electronics home-category__header__icon-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#electronics"></use></svg></span><span class="home-category__header__title">
# Multimédia
# </span><span class="home-category__header__toggle"><svg aria-hidden="true" class="i i-chevron-down home-category__header__toggle-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-down"></use></svg></span></a><div class="home-category__content"><ul class="home-category__list"><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/ordinateurs">
# Ordinateurs
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/telephones">
# Téléphones
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/accessoires-multimedia">
# Accessoires multimédia
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/jeux-videos-consoles">
# Jeux vidéos &amp; consoles
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/tv-home-cinema">
# TV &amp; home cinéma
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/tablettes">
# Tablettes
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/equipement-video-et-audio">
# Equipement vidéo et audio
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/imprimantes-scanners">
# Imprimantes &amp; scanners
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/appareils-photos">
# Appareils photos
# </a></li></ul><a class="home-category__cta" href="https://www.expat-dakar.com/multimedia"><span class="home-category__cta__title">
# Tout parcourir
# </span><span class="home-category__cta__count badge">
# 5831
# </span></a></div></div></div><div class="home-categories__item"><div class="home-category" data-home-category=""><a class="home-category__header" data-home-category-trigger="" href="https://www.expat-dakar.com/maison"><span class="home-category__header__icon"><svg aria-hidden="true" class="i i-home home-category__header__icon-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#home"></use></svg></span><span class="home-category__header__title">
# Maison
# </span><span class="home-category__header__toggle"><svg aria-hidden="true" class="i i-chevron-down home-category__header__toggle-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-down"></use></svg></span></a><div class="home-category__content"><ul class="home-category__list"><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/mobilier">
# Mobilier
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/electromenager">
# Electromenager
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/jardinage-bricolage">
# Jardinage, bricolage
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/decoration-linge-de-maison">
# Décoration, linge de maison
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/vaisselle">
# Vaisselle
# </a></li></ul><a class="home-category__cta" href="https://www.expat-dakar.com/maison"><span class="home-category__cta__title">
# Tout parcourir
# </span><span class="home-category__cta__count badge">
# 3534
# </span></a></div></div></div><div class="home-categories__item"><div class="home-category" data-home-category=""><a class="home-category__header" data-home-category-trigger="" href="https://www.expat-dakar.com/mode-beaute"><span class="home-category__header__icon"><svg aria-hidden="true" class="i i-beauty-products home-category__header__icon-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#beauty-products"></use></svg></span><span class="home-category__header__title">
# Mode &amp; beauté
# </span><span class="home-category__header__toggle"><svg aria-hidden="true" class="i i-chevron-down home-category__header__toggle-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-down"></use></svg></span></a><div class="home-category__content"><ul class="home-category__list"><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/enfant-bebe">
# Enfant &amp; bébé
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/montres-bijoux">
# Montres &amp; bijoux
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/parfums-produits-cosmetiques">
# Parfums &amp; produits cosmétiques
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/vetements-homme">
# Vêtements homme
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/chaussures-homme">
# Chaussures homme
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/cheveux-et-coiffure">
# Cheveux et coiffure
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/vetements-femme">
# Vêtements femme
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/accessoires-de-mode">
# Accessoires de mode
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/sacs-valises">
# Valises &amp; sacs
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/chaussures-femme">
# Chaussures femme
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/lingerie">
# Lingerie
# </a></li></ul><a class="home-category__cta" href="https://www.expat-dakar.com/mode-beaute"><span class="home-category__cta__title">
# Tout parcourir
# </span><span class="home-category__cta__count badge">
# 1164
# </span></a></div></div></div><div class="home-categories__item"><div class="home-category" data-home-category=""><a class="home-category__header" data-home-category-trigger="" href="https://www.expat-dakar.com/sport-loisirs-voyages"><span class="home-category__header__icon"><svg aria-hidden="true" class="i i-sports home-category__header__icon-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#sports"></use></svg></span><span class="home-category__header__title">
# Sport, loisirs &amp; voyages
# </span><span class="home-category__header__toggle"><svg aria-hidden="true" class="i i-chevron-down home-category__header__toggle-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-down"></use></svg></span></a><div class="home-category__content"><ul class="home-category__list"><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/materiel-de-sport">
# Matériel de sport
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/tourisme-activites">
# Tourisme &amp; activités
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/instruments-de-musique">
# Instruments de musique
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/velos">
# Vélos
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/cds-dvds-livres">
# CDs, DVDs &amp; livres
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/art-artisanat">
# Art &amp; artisanat
# </a></li></ul><a class="home-category__cta" href="https://www.expat-dakar.com/sport-loisirs-voyages"><span class="home-category__cta__title">
# Tout parcourir
# </span><span class="home-category__cta__count badge">
# 1214
# </span></a></div></div></div><div class="home-categories__item"><div class="home-category" data-home-category=""><a class="home-category__header" data-home-category-trigger="" href="https://www.expat-dakar.com/offres-de-services"><span class="home-category__header__icon"><svg aria-hidden="true" class="i i-professional-services home-category__header__icon-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#professional-services"></use></svg></span><span class="home-category__header__title">
# Services
# </span><span class="home-category__header__toggle"><svg aria-hidden="true" class="i i-chevron-down home-category__header__toggle-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-down"></use></svg></span></a><div class="home-category__content"><ul class="home-category__list"><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/prestations-de-service">
# Prestations de service
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/cours-particuliers">
# Cours particuliers
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/formations">
# Formations
# </a></li></ul><a class="home-category__cta" href="https://www.expat-dakar.com/offres-de-services"><span class="home-category__cta__title">
# Tout parcourir
# </span><span class="home-category__cta__count badge">
# 1094
# </span></a></div></div></div><div class="home-categories__item"><div class="home-category" data-home-category=""><a class="home-category__header" data-home-category-trigger="" href="https://www.expat-dakar.com/demandes-demploi"><span class="home-category__header__icon"><svg aria-hidden="true" class="i i-business-services home-category__header__icon-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#business-services"></use></svg></span><span class="home-category__header__title">
# Demandes d’emploi
# </span><span class="home-category__header__toggle"><svg aria-hidden="true" class="i i-chevron-down home-category__header__toggle-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-down"></use></svg></span></a><div class="home-category__content"><ul class="home-category__list"><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/autres-demandes-d-emploi">
# Autres demandes d’emploi
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/demandes-d-emploi-nettoyage-personnel">
#  Nettoyage, personnel
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/demandes-d-emploi-chauffeur-conducteur">
# Chauffeur, conducteur
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/demandes-d-emploi-nounous-garde-enfants">
# Nounous, garde d’enfants
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/demandes-d-emploi-restauration">
# Restauration
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/demandes-de-stages">
# Demande de stages
# </a></li></ul><a class="home-category__cta" href="https://www.expat-dakar.com/demandes-demploi"><span class="home-category__cta__title">
# Tout parcourir
# </span><span class="home-category__cta__count badge">
# 662
# </span></a></div></div></div><div class="home-categories__item"><div class="home-category" data-home-category=""><a class="home-category__header" data-home-category-trigger="" href="https://www.expat-dakar.com/materiaux-outils-equipements"><span class="home-category__header__icon"><svg aria-hidden="true" class="i i-trades home-category__header__icon-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#trades"></use></svg></span><span class="home-category__header__title">
# Matériaux, outils &amp; équipements
# </span><span class="home-category__header__toggle"><svg aria-hidden="true" class="i i-chevron-down home-category__header__toggle-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-down"></use></svg></span></a><div class="home-category__content"><ul class="home-category__list"><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/materiel-pro">
# Matériel pro
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/materiel-de-construction">
# Matériel de construction
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/equipement-medical">
# Equipement médical
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/energie-groupes-electrogenes">
# Energie &amp; groupes électrogènes
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/cameras-de-surveillance">
# Caméras de surveillance
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/equipement-restauration">
# Equipement restauration
# </a></li></ul><a class="home-category__cta" href="https://www.expat-dakar.com/materiaux-outils-equipements"><span class="home-category__cta__title">
# Tout parcourir
# </span><span class="home-category__cta__count badge">
# 815
# </span></a></div></div></div><div class="home-categories__item"><div class="home-category" data-home-category=""><a class="home-category__header" data-home-category-trigger="" href="https://www.expat-dakar.com/agroalimentaire"><span class="home-category__header__icon"><svg aria-hidden="true" class="i i-farming-agriculture home-category__header__icon-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#farming-agriculture"></use></svg></span><span class="home-category__header__title">
# Agroalimentaire
# </span><span class="home-category__header__toggle"><svg aria-hidden="true" class="i i-chevron-down home-category__header__toggle-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-down"></use></svg></span></a><div class="home-category__content"><ul class="home-category__list"><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/alimentation">
# Alimentation
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/agriculture">
# Agriculture
# </a></li></ul><a class="home-category__cta" href="https://www.expat-dakar.com/agroalimentaire"><span class="home-category__cta__title">
# Tout parcourir
# </span><span class="home-category__cta__count badge">
# 367
# </span></a></div></div></div><div class="home-categories__item"><div class="home-category" data-home-category=""><a class="home-category__header" data-home-category-trigger="" href="https://www.expat-dakar.com/animaux"><span class="home-category__header__icon"><svg aria-hidden="true" class="i i-pets home-category__header__icon-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#pets"></use></svg></span><span class="home-category__header__title">
# Animaux
# </span><span class="home-category__header__toggle"><svg aria-hidden="true" class="i i-chevron-down home-category__header__toggle-inner"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-down"></use></svg></span></a><div class="home-category__content"><ul class="home-category__list"><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/accessoires-animaux">
# Accessoires animaux
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/chiens-chiots">
# Chiens &amp; chiots
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/moutons">
# Moutons
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/autres-animaux">
# Autres animaux
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/pigeons">
# Pigeons
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/lapins">
# Lapins
# </a></li><li class="home-category__list-item"><a class="home-category__list-item__link" href="https://www.expat-dakar.com/chats-chatons">
# Chats &amp; chatons
# </a></li></ul><a class="home-category__cta" href="https://www.expat-dakar.com/animaux"><span class="home-category__cta__title">
# Tout parcourir
# </span><span class="home-category__cta__count badge">
# 548
# </span></a></div></div></div></div></div></div><div class="listings-slider listings-slider--classifieds" data-slider-container=""><div class="listings-slider__container"><div class="listings-slider__header"><h3 class="listings-slider__title">
# Annonces Premium
# </h3><a class="listings-slider__view-all" href="https://www.expat-dakar.com/annonces">
# Tout voir
# </a></div><div class="listings-slider__row swiper-container" data-slider="homePremiumClassifieds" data-slider-ajax="1" data-slider-ajax-endpoint="https://www.expat-dakar.com/ajax/listings/premium/0"><div class="listings-slider__slides swiper-wrapper" data-slider-wrapper=""></div></div><span class="listings-slider__nav listings-slider__nav--prev" data-slider-prev-arrow=""><svg aria-hidden="true" class="i i-chevron-left listings-slider__nav__icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-left"></use></svg></span><span class="listings-slider__nav listings-slider__nav--next" data-slider-next-arrow=""><svg aria-hidden="true" class="i i-chevron-right listings-slider__nav__icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-right"></use></svg></span></div></div><div class="listings-slider listings-slider--businesses" data-slider-container=""><div class="listings-slider__container"><div class="listings-slider__header"><h3 class="listings-slider__title">
# Premium Businesses
# </h3><a class="listings-slider__view-all" href="https://www.expat-dakar.com/entreprises">
# Tout voir
# </a></div><div class="listings-slider__row swiper-container" data-slider="homePremiumBusinesses" data-slider-ajax="1" data-slider-ajax-endpoint="https://www.expat-dakar.com/ajax/listings/premium/1"><div class="listings-slider__slides swiper-wrapper" data-slider-wrapper=""></div></div><span class="listings-slider__nav listings-slider__nav--prev" data-slider-prev-arrow=""><svg aria-hidden="true" class="i i-chevron-left listings-slider__nav__icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-left"></use></svg></span><span class="listings-slider__nav listings-slider__nav--next" data-slider-next-arrow=""><svg aria-hidden="true" class="i i-chevron-right listings-slider__nav__icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chevron-right"></use></svg></span></div></div><div class="home-ad-group--middle"><div class="home-ad-group__container"><div class="ad ad--728-90 home-ad home-ad--desktop-middle"><div class="ad__outer"><div class="ad__inner" data-ad='{"position":"desktop_middle","route":"homeClassified","width":728,"height":90,"dfp":{"path":"\/59134517\/Expat_Dakar_Home_728x90","id":"101586037"},"bids":[],"url":"#","picture":null}' id="101586037"></div></div></div></div></div><section class="home-product"><div class="home-product__container"><div class="home-product__inner"><div class="home-product__content"><h5 class="home-product__title">
# Développez votre business. Commencez à vendre dès aujourd'hui avec Expat-Dakar !
# </h5><p class="home-product__subtitle">
# Nous avons créé un ensemble de forfaits sur mesure pour dynamiser, promouvoir et mettre en valeur votre entreprise ou votre annonce.
# </p><div class="home-product__btn"><a class="home-product__btn-link btn btn-secondary" href="https://www.expat-dakar.com/vendre-en-ligne">
# En savoir plus
# </a></div></div></div></div></section></div><section class="home-newsletter"><div class="home-newsletter__container"><div class="home-newsletter__inner"><div class="home-newsletter__content"><div class="home-newsletter__title">
# Restez informés avec notre newsletter
# </div><p class="home-newsletter__subtitle">
# Recevez chaque semaine notre sélection personnalisée des meilleures offres !
# </p></div><div class="home-newsletter__form-container"><form accept-charset="UTF-8" action="https://www.expat-dakar.com/newsletter-subscribe" class="home-newsletter__form" data-form-blocking="" data-remote="" data-t-newsletter-subscribe="" data-type="json" data-validate-form="" method="POST"><input name="_token" type="hidden" value="aRVOiL2tKmhF9fWEq7LAQDSx5FAeIfaMdtYjrO8q"/><input name="source" type="hidden" value="website form"/><label class="sr-only" for="more_details_newsletter">Additional details required</label><input aria-label="Additional details required" class="form-control form-control--more-details" id="more_details_newsletter" name="more_details" type="text"/><div class="home-newsletter__form__inner"><div class="home-newsletter__form__email"><label class="sr-only" for="email_newsletter">Adresse e-mail</label><input class="form-control home-newsletter__form__email-input" id="email_newsletter" name="email" placeholder="Adresse e-mail" required="" type="email"/></div><div class="home-newsletter__form__submit"><button class="btn btn-secondary btn-block" id="newsletter-subscribe" type="submit">
# Souscrire
# </button></div></div></form></div></div></div></section><footer class="footer"><div class="footer__container"><div class="footer__row"><div class="footer-group"><div class="footer-group__inner"><div class="footer-links footer-links--links"><ul class="footer-links__list"><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/qui-sommes-nous">
# Qui sommes-nous ?
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/contact">
# Contact
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/vendre-en-ligne">
# Vendre en ligne
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/deals">
# Deals
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/blog">
# Blog
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/conditions-utilisation">
# Conditions et Charte d'utilisation
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/showroom">
# Showrooms
# </a></li></ul></div><div class="footer-links footer-links--partners"><div class="footer-links__header">
# Sites internationaux
# </div><ul class="footer-links__list"><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://roam.africa" rel="noopener" target="_blank">
# ROAM
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://qefira.com" rel="noopener" target="_blank">
# Qefira
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://pigiame.co.ke" rel="noopener" target="_blank">
# Pigiame
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://zoomtanzania.com" rel="noopener" target="_blank">
# ZoomTanzania
# </a></li></ul></div></div></div><div class="footer-links footer-links--social"><div class="footer-links__header">
# Suivre Expat-Dakar
# </div><ul class="footer-links__list footer-links__list-social"><li class="footer-links__list-social-item"><a class="ic ic--facebook footer-links__list-social-item__network footer-links__list-social-item__network--facebook" href="https://www.facebook.com/expatdakar/" rel="noopener nofollow" target="_blank"><svg aria-hidden="true" class="i i-facebook"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#facebook"></use></svg><span class="footer-links__list-social-item__network-title">
# Suivez Expat-Dakar on Facebook
# </span></a></li><li class="footer-links__list-social-item"><a class="ic ic--twitter footer-links__list-social-item__network footer-links__list-social-item__network--twitter" href="https://twitter.com/expatdakar" rel="noopener nofollow" target="_blank"><svg aria-hidden="true" class="i i-twitter"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#twitter"></use></svg><span class="footer-links__list-social-item__network-title">
# Suivez Expat-Dakar on Twitter
# </span></a></li><li class="footer-links__list-social-item"><a class="ic ic--instagram footer-links__list-social-item__network footer-links__list-social-item__network--instagram" href="https://www.instagram.com/expatdakar/" rel="noopener nofollow" target="_blank"><svg aria-hidden="true" class="i i-instagram"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#instagram"></use></svg><span class="footer-links__list-social-item__network-title">
# Suivez Expat-Dakar on Instagram
# </span></a></li><li class="footer-links__list-social-item"><a class="ic ic--linkedin footer-links__list-social-item__network footer-links__list-social-item__network--linkedin" href="https://www.linkedin.com/company/expat-dakar/" rel="noopener nofollow" target="_blank"><svg aria-hidden="true" class="i i-linkedin"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#linkedin"></use></svg><span class="footer-links__list-social-item__network-title">
# Suivez Expat-Dakar on LinkedIn
# </span></a></li></ul></div></div></div><div class="footer-copyright"><div class="footer-copyright__container"><div class="footer-copyright__inner"><div class="footer-copyright__notice">
# Tous droits réservés © 2016-2021 Expat-Dakar
# </div></div></div></div></footer></div>, <div class="ad ad--970-90 home-ad home-ad--desktop-header"><div class="ad__outer"><div class="ad__inner" data-ad='{"position":"desktop_header","route":"homeClassified","width":970,"height":90,"dfp":{"path":"\/59134517\/ED_HomeClassified_DH_970x90","id":"22395324735"},"bids":[],"url":"#","picture":null}' id="22395324735"></div></div></div>, <div class="ad__outer"><div class="ad__inner" data-ad='{"position":"desktop_header","route":"homeClassified","width":970,"height":90,"dfp":{"path":"\/59134517\/ED_HomeClassified_DH_970x90","id":"22395324735"},"bids":[],"url":"#","picture":null}' id="22395324735"></div></div>, <div class="ad__inner" data-ad='{"position":"desktop_header","route":"homeClassified","width":970,"height":90,"dfp":{"path":"\/59134517\/ED_HomeClassified_DH_970x90","id":"22395324735"},"bids":[],"url":"#","picture":null}' id="22395324735"></div>, <div class="header-bar"><div class="header-bar__inner"><div class="header-auth"><a class="btn btn-default header-auth__item" href="https://www.expat-dakar.com/compte/login">
# Connexion / Inscription
# </a></div></div></div>, <div class="header-bar__inner"><div class="header-auth"><a class="btn btn-default header-auth__item" href="https://www.expat-dakar.com/compte/login">
# Connexion / Inscription
# </a></div></div>, <div class="header-auth"><a class="btn btn-default header-auth__item" href="https://www.expat-dakar.com/compte/login">
# Connexion / Inscription
# </a></div>, <div class="header__inner"><a class="header-logo" href="https://www.expat-dakar.com"><span class="header-logo__brand">
# Expat-Dakar
# </span><img alt="Expat-Dakar" class="header-logo__img" src="https://www.expat-dakar.com/assets/ed-site/img/logo-colour.074b1f6c.svg"/></a><span class="header-spacer"> </span><div class="header-cta"><a class="btn btn-secondary header-cta__button" href="https://www.expat-dakar.com/compte/listing/create/listing"><span class="header-cta__button-title">
# Vendre
# </span></a></div><span class="header-menu-toggle"><a aria-label="Menu" class="btn header-menu-toggle__button" data-menu-nav-toggle="" href="#"><svg aria-hidden="true" class="i i-menu header-menu-toggle__button-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#menu"></use></svg></a></span><div class="global-search"><div class="global-search__inner"><form accept-charset="UTF-8" action="https://www.expat-dakar.com/annonces" class="global-search__form" method="GET"><div class="global-search__query"><label class="sr-only" for="q">Recherche par texte</label><input class="form-control autocomplete global-search__query-input" data-autocomplete='{"appendTo":".global-search__inner"}' data-url="https://www.expat-dakar.com/ajax/suggestions?is_business=0" id="q" name="q" placeholder="Je recherche..." type="text"/><svg aria-hidden="true" class="i i-magnify global-search__query-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#magnify"></use></svg></div><div class="global-search__button"><button class="btn btn-primary global-search__button-btn" type="submit">
# Rechercher
# </button></div></form></div></div></div>, <div class="header-cta"><a class="btn btn-secondary header-cta__button" href="https://www.expat-dakar.com/compte/listing/create/listing"><span class="header-cta__button-title">
# Vendre
# </span></a></div>, <div class="global-search"><div class="global-search__inner"><form accept-charset="UTF-8" action="https://www.expat-dakar.com/annonces" class="global-search__form" method="GET"><div class="global-search__query"><label class="sr-only" for="q">Recherche par texte</label><input class="form-control autocomplete global-search__query-input" data-autocomplete='{"appendTo":".global-search__inner"}' data-url="https://www.expat-dakar.com/ajax/suggestions?is_business=0" id="q" name="q" placeholder="Je recherche..." type="text"/><svg aria-hidden="true" class="i i-magnify global-search__query-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#magnify"></use></svg></div><div class="global-search__button"><button class="btn btn-primary global-search__button-btn" type="submit">
# Rechercher
# </button></div></form></div></div>, <div class="global-search__inner"><form accept-charset="UTF-8" action="https://www.expat-dakar.com/annonces" class="global-search__form" method="GET"><div class="global-search__query"><label class="sr-only" for="q">Recherche par texte</label><input class="form-control autocomplete global-search__query-input" data-autocomplete='{"appendTo":".global-search__inner"}' data-url="https://www.expat-dakar.com/ajax/suggestions?is_business=0" id="q" name="q" placeholder="Je recherche..." type="text"/><svg aria-hidden="true" class="i i-magnify global-search__query-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#magnify"></use></svg></div><div class="global-search__button"><button class="btn btn-primary global-search__button-btn" type="submit">
# Rechercher
# </button></div></form></div>, <div class="global-search__query"><label class="sr-only" for="q">Recherche par texte</label><input class="form-control autocomplete global-search__query-input" data-autocomplete='{"appendTo":".global-search__inner"}' data-url="https://www.expat-dakar.com/ajax/suggestions?is_business=0" id="q" name="q" placeholder="Je recherche..." type="text"/><svg aria-hidden="true" class="i i-magnify global-search__query-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#magnify"></use></svg></div>, <div class="global-search__button"><button class="btn btn-primary global-search__button-btn" type="submit">
# Rechercher
# ...
# Contact
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/vendre-en-ligne">
# Vendre en ligne
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/deals">
# Deals
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/blog">
# Blog
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/conditions-utilisation">
# Conditions et Charte d'utilisation
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/showroom">
# Showrooms
# </a></li></ul></div><div class="footer-links footer-links--partners"><div class="footer-links__header">
# Sites internationaux
# </div><ul class="footer-links__list"><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://roam.africa" rel="noopener" target="_blank">
# ROAM
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://qefira.com" rel="noopener" target="_blank">
# Qefira
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://pigiame.co.ke" rel="noopener" target="_blank">
# Pigiame
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://zoomtanzania.com" rel="noopener" target="_blank">
# ZoomTanzania
# </a></li></ul></div></div>, <div class="footer-links footer-links--links"><ul class="footer-links__list"><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/qui-sommes-nous">
# Qui sommes-nous ?
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/contact">
# Contact
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/vendre-en-ligne">
# Vendre en ligne
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/deals">
# Deals
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/blog">
# Blog
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/conditions-utilisation">
# Conditions et Charte d'utilisation
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/showroom">
# Showrooms
# </a></li></ul></div>, <div class="footer-links footer-links--partners"><div class="footer-links__header">
# Sites internationaux
# </div><ul class="footer-links__list"><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://roam.africa" rel="noopener" target="_blank">
# ROAM
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://qefira.com" rel="noopener" target="_blank">
# Qefira
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://pigiame.co.ke" rel="noopener" target="_blank">
# Pigiame
# </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://zoomtanzania.com" rel="noopener" target="_blank">
# ZoomTanzania
# </a></li></ul></div>, <div class="footer-links__header">
# Sites internationaux
# </div>, <div class="footer-links footer-links--social"><div class="footer-links__header">
# Suivre Expat-Dakar
# </div><ul class="footer-links__list footer-links__list-social"><li class="footer-links__list-social-item"><a class="ic ic--facebook footer-links__list-social-item__network footer-links__list-social-item__network--facebook" href="https://www.facebook.com/expatdakar/" rel="noopener nofollow" target="_blank"><svg aria-hidden="true" class="i i-facebook"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#facebook"></use></svg><span class="footer-links__list-social-item__network-title">
# Suivez Expat-Dakar on Facebook
# </span></a></li><li class="footer-links__list-social-item"><a class="ic ic--twitter footer-links__list-social-item__network footer-links__list-social-item__network--twitter" href="https://twitter.com/expatdakar" rel="noopener nofollow" target="_blank"><svg aria-hidden="true" class="i i-twitter"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#twitter"></use></svg><span class="footer-links__list-social-item__network-title">
# Suivez Expat-Dakar on Twitter
# </span></a></li><li class="footer-links__list-social-item"><a class="ic ic--instagram footer-links__list-social-item__network footer-links__list-social-item__network--instagram" href="https://www.instagram.com/expatdakar/" rel="noopener nofollow" target="_blank"><svg aria-hidden="true" class="i i-instagram"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#instagram"></use></svg><span class="footer-links__list-social-item__network-title">
# Suivez Expat-Dakar on Instagram
# </span></a></li><li class="footer-links__list-social-item"><a class="ic ic--linkedin footer-links__list-social-item__network footer-links__list-social-item__network--linkedin" href="https://www.linkedin.com/company/expat-dakar/" rel="noopener nofollow" target="_blank"><svg aria-hidden="true" class="i i-linkedin"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#linkedin"></use></svg><span class="footer-links__list-social-item__network-title">
# Suivez Expat-Dakar on LinkedIn
# </span></a></li></ul></div>, <div class="footer-links__header">
# Suivre Expat-Dakar
# </div>, <div class="footer-copyright"><div class="footer-copyright__container"><div class="footer-copyright__inner"><div class="footer-copyright__notice">
# Tous droits réservés © 2016-2021 Expat-Dakar
# </div></div></div></div>, <div class="footer-copyright__container"><div class="footer-copyright__inner"><div class="footer-copyright__notice">
# Tous droits réservés © 2016-2021 Expat-Dakar
# </div></div></div>, <div class="footer-copyright__inner"><div class="footer-copyright__notice">
# Tous droits réservés © 2016-2021 Expat-Dakar
# </div></div>, <div class="footer-copyright__notice">
# Tous droits réservés © 2016-2021 Expat-Dakar
# </div>, <div class="menu-nav__inner"><div class="menu-nav__header"><span class="menu-nav-toggle"><a class="btn menu-nav-toggle__button" data-menu-nav-toggle="" href="#"><svg aria-hidden="true" class="i i-close menu-nav-toggle__button-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#close"></use></svg></a></span><a class="header-logo" href="https://www.expat-dakar.com"><span class="header-logo__brand">
# Expat-Dakar
# </span><img alt="Expat-Dakar" class="header-logo__img" src="https://www.expat-dakar.com/assets/ed-site/img/logo-colour.074b1f6c.svg"/></a><span class="header-spacer"> </span><div class="header-cta"><a class="btn btn-secondary header-cta__button" href="https://www.expat-dakar.com/compte/listing/create/listing"><span class="header-cta__button-title">
# Vendre
# </span></a></div></div><ul class="menu-nav__list"><li class="menu-nav__list-item"><div class="menu-nav__list-item__header">
# Mon Profil
# </div></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/compte/login">
# Connexion / Inscription
# </a></li><li class="menu-nav__list-item"><div class="menu-nav__list-item__header">
# Catégories
# </div></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/showroom"><svg aria-hidden="true" class="i i-briefcase"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#briefcase"></use></svg>
# Showrooms
# </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com"><svg aria-hidden="true" class="i i-account"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#account"></use></svg>
# Petites annonces
# </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/agroalimentaire"><svg aria-hidden="true" class="i i-farming-agriculture"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#farming-agriculture"></use></svg>
# Agroalimentaire
# </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/animaux"><svg aria-hidden="true" class="i i-pets"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#pets"></use></svg>
# Animaux
# </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/demandes-demploi"><svg aria-hidden="true" class="i i-business-services"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#business-services"></use></svg>
# Demandes d’emploi
# </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/immobilier"><svg aria-hidden="true" class="i i-home"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#home"></use></svg>
# Immobilier
# </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/maison"><svg aria-hidden="true" class="i i-home"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#home"></use></svg>
# Maison
# </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/materiaux-outils-equipements"><svg aria-hidden="true" class="i i-trades"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#trades"></use></svg>
# Matériaux, outils &amp; équipements
# </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/mode-beaute"><svg aria-hidden="true" class="i i-beauty-products"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#beauty-products"></use></svg>
# Mode &amp; beauté
# </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/multimedia"><svg aria-hidden="true" class="i i-electronics"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#electronics"></use></svg>
# Multimédia
# </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/emploi"><svg aria-hidden="true" class="i i-jobs"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#jobs"></use></svg>
# Offres d'emploi
# </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/offres-de-services"><svg aria-hidden="true" class="i i-professional-services"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#professional-services"></use></svg>
# Services
# </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/sport-loisirs-voyages"><svg aria-hidden="true" class="i i-sports"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#sports"></use></svg>
#  Sport, loisirs &amp; voyages
# </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/vehicules"><svg aria-hidden="true" class="i i-vehicles"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#vehicles"></use></svg>
# Véhicules
# </a></li></ul></div>, <div class="menu-nav__header"><span class="menu-nav-toggle"><a class="btn menu-nav-toggle__button" data-menu-nav-toggle="" href="#"><svg aria-hidden="true" class="i i-close menu-nav-toggle__button-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#close"></use></svg></a></span><a class="header-logo" href="https://www.expat-dakar.com"><span class="header-logo__brand">
# Expat-Dakar
# </span><img alt="Expat-Dakar" class="header-logo__img" src="https://www.expat-dakar.com/assets/ed-site/img/logo-colour.074b1f6c.svg"/></a><span class="header-spacer"> </span><div class="header-cta"><a class="btn btn-secondary header-cta__button" href="https://www.expat-dakar.com/compte/listing/create/listing"><span class="header-cta__button-title">
# Vendre
# </span></a></div></div>, <div class="header-cta"><a class="btn btn-secondary header-cta__button" href="https://www.expat-dakar.com/compte/listing/create/listing"><span class="header-cta__button-title">
# Vendre
# </span></a></div>, <div class="menu-nav__list-item__header">
# Mon Profil
# </div>, <div class="menu-nav__list-item__header">
# Catégories
# </div>, <div class="js-cookie-consent cookie-consent"><div class="cookie-consent__container"><div class="cookie-consent__inner"><div class="cookie-consent__message"><p>Bonjour, nous utilisons des cookies pour vous offrir une meilleure expérience de navigation et pour analyser le trafic du site. En continuant à utiliser notre site Web, vous consentez à l'utilisation de ces cookies. <a href="https://www.expat-dakar.com/conditions-utilisation"> En savoir plus </a>.</p></div><div class="cookie-consent__agree"><button class="js-cookie-consent-agree btn btn-primary btn-sm">
# Accepter
# </button></div></div></div></div>, <div class="cookie-consent__container"><div class="cookie-consent__inner"><div class="cookie-consent__message"><p>Bonjour, nous utilisons des cookies pour vous offrir une meilleure expérience de navigation et pour analyser le trafic du site. En continuant à utiliser notre site Web, vous consentez à l'utilisation de ces cookies. <a href="https://www.expat-dakar.com/conditions-utilisation"> En savoir plus </a>.</p></div><div class="cookie-consent__agree"><button class="js-cookie-consent-agree btn btn-primary btn-sm">
# Accepter
# </button></div></div></div>, <div class="cookie-consent__inner"><div class="cookie-consent__message"><p>Bonjour, nous utilisons des cookies pour vous offrir une meilleure expérience de navigation et pour analyser le trafic du site. En continuant à utiliser notre site Web, vous consentez à l'utilisation de ces cookies. <a href="https://www.expat-dakar.com/conditions-utilisation"> En savoir plus </a>.</p></div><div class="cookie-consent__agree"><button class="js-cookie-consent-agree btn btn-primary btn-sm">
# Accepter
# </button></div></div>, <div class="cookie-consent__message"><p>Bonjour, nous utilisons des cookies pour vous offrir une meilleure expérience de navigation et pour analyser le trafic du site. En continuant à utiliser notre site Web, vous consentez à l'utilisation de ces cookies. <a href="https://www.expat-dakar.com/conditions-utilisation"> En savoir plus </a>.</p></div>, <div class="cookie-consent__agree"><button class="js-cookie-consent-agree btn btn-primary btn-sm">
# Accepter
# </button></div>, <div class="modal-workflow modal" id="modal-view" role="dialog" tabindex="-1"><div class="modal-dialog" role="document"><div class="modal-content"><div class="modal-header"><div class="modal-title">
# Title
# </div></div><div class="modal-body">
# Body
# </div></div></div></div>, <div class="modal-dialog" role="document"><div class="modal-content"><div class="modal-header"><div class="modal-title">
# Title
# </div></div><div class="modal-body">
# Body
# </div></div></div>, <div class="modal-content"><div class="modal-header"><div class="modal-title">
# Title
# </div></div><div class="modal-body">
# Body
# </div></div>, <div class="modal-header"><div class="modal-title">
# Title
# </div></div>, <div class="modal-title">
# Title
# </div>, <div class="modal-body">
# Body
# </div>, <div class="backdrop"> </div>]
