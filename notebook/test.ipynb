# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Récupérer le contenu html de la page:
#
# On prendra le soin de définir quelques variables avant: url et headers

# %%
url = "https://www.expat-dakar.com/immobilier"
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:64.0) Gecko/20100101 Firefox/64.0'
}

token = 'https://www.expat-dakar.com/appartements-a-louer?page='
def get_pages(token, nb):
    pages = []
    for i in range(1,nb+1):
        j = token + str(i)
        pages.append(j)
    return pages
pages = get_pages(token,38)

import requests
for i in pages:
   response = requests.get(i ,headers=headers)
   print(response.status_code)
#response = requests.get(url, headers=headers)
# Out:
# 404
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %% [markdown]
# # Confirmer que le html a été téléchargé avec succès

# %%
import bs4
soup = bs4.BeautifulSoup(response.text, 'html.parser')
#resul = soup.find_all("div", {"class":"listing-card__header__title","class":"listing-card__date-line"})
#resul = soup.find_all("div", {"class":"listing-card listing-card--tab listing-card--has-contact listing-card--has-content listing-card--highlight-placeholder"})
resultat=soup.find_all("a",{"class":"listing-card__inner"})
#print(resul)
print(resultat)
# Out:
# [<a class="listing-card__inner" data-t-listing="" data-t-listing_category_slug="appartements-a-louer" data-t-listing_category_title="Appartements à louer" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="3300427" data-t-listing_location_title="Almadies" data-t-listing_price="1400000.00" data-t-listing_product_slugs="expiring-gold-priority|listing|paid-listing" data-t-listing_slug="bel-appartement-a-ngor-almadies" data-t-listing_source="ed_sn" data-t-listing_title="BEL APPARTEMENT NEUF AUX ALMADIES" data-t-listing_type="classified" href="https://www.expat-dakar.com/annonce/bel-appartement-a-ngor-almadies-3300427" id="listing-3300427"><div class="listing-card__aside"><div class="listing-card__image"><div class="listing-card__image__inner-container"><svg aria-hidden="true" class="i i-home listing-card__image__placeholder"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#home"></use></svg><div class="listing-card__ima
# ...

# %%
<div class="listing-card listing-card--tab listing-card--has-contact listing-card--has-content listing-card--highlight-placeholder"><a href="https://www.expat-dakar.com/annonce/bel-appartement-f4-neuf-grand-standing-a-louer-au-point-e-2732324" class="listing-card__inner" id="listing-2732324" data-t-listing="" data-t-listing_context="search" data-t-listing_id="2732324" data-t-listing_title="Bel appartement F4 neuf grand standing à louer au Point E" data-t-listing_type="classified" data-t-listing_category_title="Appartements à louer" data-t-listing_category_slug="appartements-a-louer" data-t-listing_slug="bel-appartement-f4-neuf-grand-standing-a-louer-au-point-e" data-t-listing_price="1200000.00" data-t-listing_currency="XOF" data-t-listing_location_title="Fann Point-E Amitié" data-t-listing_source="ed_sn" data-t-listing_product_slugs="listing"><div class="listing-card__aside"><div class="listing-card__image"><div class="listing-card__image__inner-container"><svg class="i i-home listing-card__image__placeholder" aria-hidden="true"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.e20f81e5.svg#home"></use></svg><div class="listing-card__image__inner"><img class="listing-card__image__resource vh-img" alt="Bel appartement F4 neuf grand standing à louer au Point E" src="https://i.roamcdn.net/hz/ed/listing-thumb-112w/05054f198f9ff880cdc53e56f5c3db05/-/horizon-files-prod/ed/picture/migrated/qm6j5nd/65832fba4a42b6d4e362949b4fe10966c1da117b.jpg" loading="lazy" srcset="https://i.roamcdn.net/hz/ed/listing-thumb-112w/05054f198f9ff880cdc53e56f5c3db05/-/horizon-files-prod/ed/picture/migrated/qm6j5nd/65832fba4a42b6d4e362949b4fe10966c1da117b.jpg 112w,https://i.roamcdn.net/hz/ed/listing-thumb-224w/814327b6603b90ed10a7b0280263ec9b/-/horizon-files-prod/ed/picture/migrated/qm6j5nd/65832fba4a42b6d4e362949b4fe10966c1da117b.jpg 224w,https://i.roamcdn.net/hz/ed/listing-thumb-180w/362621463bca5fe504700313edeae4fa/-/horizon-files-prod/ed/picture/migrated/qm6j5nd/65832fba4a42b6d4e362949b4fe10966c1da117b.jpg 180w,https://i.roamcdn.net/hz/ed/listing-thumb-360w/f9c6cf40989b06084bc02b13e9c042be/-/horizon-files-prod/ed/picture/migrated/qm6j5nd/65832fba4a42b6d4e362949b4fe10966c1da117b.jpg 360w"></div></div></div></div><div class="listing-card__content"><div class="listing-card__content__inner"><div class="listing-card__header"><div class="listing-card__header-content"><div class="listing-card__header__title">
Bel appartement F4 neuf grand standing à louer au Point E
</div><div class="listing-card__header__tags"></div><div class="listing-card__header__location"><svg class="i i-gmaps " aria-hidden="true"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#gmaps"></use></svg>
Fann Point-E Amitié,
Dakar
</div></div></div><div class="listing-card__date-line"><div class="listing-card__header__date">
12. oct. '20, 16:18
</div></div><div class="listing-card__info-bar"><div class="listing-card__info-bar__price"><span class="listing-card__price"><span class="listing-card__price__value">
1 200 000 F Cfa
</span></span></div><!--googleoff: index--><div class="listing-card__info-bar__contact"><object class="listing-card__contact listing-card__contact--phone" alt="Contacter via Phone"><form method="POST" action="https://www.expat-dakar.com/annonce/bel-appartement-f4-neuf-grand-standing-a-louer-au-point-e-2732324/view-phone" accept-charset="UTF-8" class="listing-card__contact__container" data-listing-card-show-phone="" data-listing-card-show-phone-container=".listing-card" data-listing-card-show-phone-popover=".listing-card__contact__number" data-t-enquiry-show="" data-t-contact_type="phone" data-t-contact_context="card" data-t-listing_id="2732324" data-t-listing_title="Bel appartement F4 neuf grand standing à louer au Point E" data-t-listing_type="classified" data-t-listing_category_title="Appartements à louer" data-t-listing_category_slug="appartements-a-louer" data-t-listing_slug="bel-appartement-f4-neuf-grand-standing-a-louer-au-point-e" data-t-listing_price="1200000.00" data-t-listing_currency="XOF" data-t-listing_location_title="Fann Point-E Amitié" data-t-listing_source="ed_sn" data-t-listing_product_slugs="listing" data-t-listing_context="search"><input name="_token" type="hidden" value="RSxNexMTxIhhXPP8TVglCKT12P7FF4VCqXDaLQtz"><button type="submit" class="listing-card__contact__icon-outer" aria-label="Contacter via Phone"><svg class="i i-phone listing-card__contact__icon" aria-hidden="true"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#phone"></use></svg></button><div class="listing-card__contact__number"><a href="tel:+221775225352" class="listing-card__contact__number-inner" data-t-enquiry-submit="" data-t-contact_type="phone" data-t-contact_context="card" data-t-listing_id="2732324" data-t-listing_title="Bel appartement F4 neuf grand standing à louer au Point E" data-t-listing_type="classified" data-t-listing_category_title="Appartements à louer" data-t-listing_category_slug="appartements-a-louer" data-t-listing_slug="bel-appartement-f4-neuf-grand-standing-a-louer-au-point-e" data-t-listing_price="1200000.00" data-t-listing_currency="XOF" data-t-listing_location_title="Fann Point-E Amitié" data-t-listing_source="ed_sn" data-t-listing_product_slugs="listing" data-t-listing_context="search">
775225352
</a><a href="tel:+221778930035" class="listing-card__contact__number-inner" data-t-enquiry-submit="" data-t-contact_type="phone" data-t-contact_context="card" data-t-listing_id="2732324" data-t-listing_title="Bel appartement F4 neuf grand standing à louer au Point E" data-t-listing_type="classified" data-t-listing_category_title="Appartements à louer" data-t-listing_category_slug="appartements-a-louer" data-t-listing_slug="bel-appartement-f4-neuf-grand-standing-a-louer-au-point-e" data-t-listing_price="1200000.00" data-t-listing_currency="XOF" data-t-listing_location_title="Fann Point-E Amitié" data-t-listing_source="ed_sn" data-t-listing_product_slugs="listing" data-t-listing_context="search">
778930035
</a></div></form></object><object class="listing-card__contact listing-card__contact--whatsapp" alt="Contacter via WhatsApp"><div class="listing-card__contact__container"><a class="listing-card__contact__icon-outer" rel="noopener noindex nofollow" href="whatsapp://send?abid=%2B221775225352&amp;phone=%2B221775225352&amp;text=Salut%2C%20je%20suis%20int%C3%A9ress%C3%A9%20par%20votre%20annonce%20%3A%20https%3A%2F%2Fwww.expat-dakar.com%2Fannonce%2Fbel-appartement-f4-neuf-grand-standing-a-louer-au-point-e-2732324%20sur%20Expat-Dakar" aria-label="Contacter via WhatsApp" data-whatsapp="https://wa.me/221775225352?text=Salut%2C+je+suis+int%C3%A9ress%C3%A9+par+votre+annonce+%3A+https%3A%2F%2Fwww.expat-dakar.com%2Fannonce%2Fbel-appartement-f4-neuf-grand-standing-a-louer-au-point-e-2732324+sur+Expat-Dakar" data-whatsapp-track="https://www.expat-dakar.com/annonce/bel-appartement-f4-neuf-grand-standing-a-louer-au-point-e-2732324/view-whatsapp" data-t-enquiry-submit="" data-t-contact_type="whatsapp" data-t-contact_context="card" data-t-listing_id="2732324" data-t-listing_title="Bel appartement F4 neuf grand standing à louer au Point E" data-t-listing_type="classified" data-t-listing_category_title="Appartements à louer" data-t-listing_category_slug="appartements-a-louer" data-t-listing_slug="bel-appartement-f4-neuf-grand-standing-a-louer-au-point-e" data-t-listing_price="1200000.00" data-t-listing_currency="XOF" data-t-listing_location_title="Fann Point-E Amitié" data-t-listing_source="ed_sn" data-t-listing_product_slugs="listing" data-t-listing_context="search"><svg class="i i-whatsapp listing-card__contact__icon" aria-hidden="true"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#whatsapp"></use></svg></a></div></object><object class="listing-card__contact listing-card__contact--chat" alt="Contacter via Chat"><form method="GET" action="https://www.expat-dakar.com/compte/profile/mobile-verify/send" accept-charset="UTF-8" class="listing-card__contact__container" data-t-enquiry-auth="" data-t-contact_type="chat" data-t-contact_context="card" data-t-listing_id="2732324" data-t-listing_title="Bel appartement F4 neuf grand standing à louer au Point E" data-t-listing_type="classified" data-t-listing_category_title="Appartements à louer" data-t-listing_category_slug="appartements-a-louer" data-t-listing_slug="bel-appartement-f4-neuf-grand-standing-a-louer-au-point-e" data-t-listing_price="1200000.00" data-t-listing_currency="XOF" data-t-listing_location_title="Fann Point-E Amitié" data-t-listing_source="ed_sn" data-t-listing_product_slugs="listing" data-t-listing_context="search"><input name="redirect" type="hidden" value="https://www.expat-dakar.com/appartements-a-louer?page=38"><input name="require_mobile_verified" type="hidden" value="1"><input name="trigger_contact[id]" type="hidden" value="2732324"><input name="trigger_contact[type]" type="hidden" value="chat"><button type="submit" class="listing-card__contact__icon-outer" aria-label="Contacter via Chat"><svg class="i i-chat listing-card__contact__icon" aria-hidden="true"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.f21becaf.svg#chat"></use></svg></button></form></object></div><!--googleon: index--></div></div></div></a></div>

# %%
parameters = ["listing-card__date-line","listing-card__header__date"]
df_f = pd.DataFrame()
for par in parameters:
    l = []
    for el in resul:
        j = el[par]
        l.append(j)
    l = pd.DataFrame(l, columns = [par])
    df_f = pd.concat([df_f,l], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-ce7d61c44a1b> in <module>
#       4     l = []
#       5     for el in resul:
# ----> 6         j = el[par]
#       7         l.append(j)
#       8     l = pd.DataFrame(l, columns = [par])
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1404         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1405         and throws an exception if it's not there."""
# -> 1406         return self.attrs[key]
#    1407
#    1408     def __iter__(self):
#
# KeyError: 'listing-card__date-line'

# %%
,"class":"data-t-listing_price","class":"data-t-listing_location_title","class":"data-t-listing_id","class":"listing-card__header__tags__item--no-of-bedrooms","class":"data-t-listing_category_slug"
resul = soup.find_all("div", {"class":"listing-card__header__title","class":"listing-card__date-line",data-t-listing_price,data-t-listing_location_title,data-t-listing_id="3374384", listing-card__header__tags__item--no-of-bedrooms,data-t-listing_category_slug})
</a><a class="listing-card__contact__number-inner" data-t-contact_context="card" data-t-contact_type="phone" data-t-enquiry-submit="" data-t-listing_category_slug="appartements-a-louer" data-t-listing_category_title="Appartements à louer" data-t-listing_context="similar" data-t-listing_currency="XOF" data-t-listing_id="3374384" data-t-listing_location_title="Parcelles Assainies" data-t-listing_price="175000.00" data-t-listing_product_slugs="listing|paid-listing" data-t-listing_slug="appartement-a-la-cite-damel" data-t-listing_source="ed_sn" data-t-listing_title="APPARTEMENT A LA CITE DAMEL" data-t-listing_type="classified" href="tel:+221338209292">
# Out:
#   File "<ipython-input-25-f992bda3a811>", line 1
#     "class":"data-t-listing_price","class":"data-t-listing_location_title","class":"data-t-listing_id","class":"listing-card__header__tags__item--no-of-bedrooms","class":"data-t-listing_category_slug"("")
#                                   ^
# SyntaxError: invalid syntax

# %%
par
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-47f557b760ee> in <module>
#       4     l = []
#       5     for el in resul:
# ----> 6         j = el[par]
#       7         l.append(j)
#       8     l = pd.DataFrame(l, columns = [par])
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1404         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1405         and throws an exception if it's not there."""
# -> 1406         return self.attrs[key]
#    1407
#    1408     def __iter__(self):
#
# KeyError: 'listing-card--tab'

# %% [markdown]
# # Sauvegarder le contenu html dans une variable

# %%
html_data = response.text

# %% [markdown]
# # Exploration du contenu html avec BeautifulSoup
#
# On prendra la peine de définir quelques variables

# %%
soup = BeautifulSoup(html_data)

# %%
#lista=[]
resulta = soup.find_all('div',attrs= {'listing-card ': 'listing-card--highlight-placeholder'})
print(resulta)

# %%
all_schools = [] # liste des écoles
all_articles = soup.find_all('article', attrs={'data-role': 'company'})

for artcl in all_articles:
    school = {} # objet dictionnaire caractérisant une école
    
    school["name"] = artcl.find('a', attrs={"class":"stretched-link"}).text.replace('\n', '').strip()
    school["address"] = artcl.find('address').text.replace('<br/>', ' ').strip()
    school["tel"] = artcl.find('div', attrs={"class":"flex flex-1 t:ml-10 min-w-180px"}).find('a').get('href').replace('tel:','')
    
    all_schools.append(school) # ajout de l'objet école dans la liste des écoles

# %%
data-t-listing_price = soup.find_all('a', {'class': 'data-t-listing_price'})
print(data-t-listing_price)
